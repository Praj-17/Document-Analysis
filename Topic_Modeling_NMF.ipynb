# %%
import pandas as pd
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer
documents = pd.read_csv('data_topic_model.csv', error_bad_lines=False)
documents.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0                                             Review
# 0           0  Bosses are used to facilitate the registration...
# 1           1  Ribs are used in a design to increase the bend...
# 2           2  Mold drafts facilitate part removal from the m...
# 3           3  Inserts used in plastic parts provide a place ...
# 4           4  Ultrasonic insertion is when an insert is “vib...

# %%
# use tfidf by removing tokens that don't appear in at least 50 documents
vect = TfidfVectorizer(min_df=1, stop_words='english')
# Fit and transform
X = vect.fit_transform(documents.Review)

# %%
documents,min
# Out:
# (    Unnamed: 0                                             Review
#  0            0  Bosses are used to facilitate the registration...
#  1            1  Ribs are used in a design to increase the bend...
#  2            2  Mold drafts facilitate part removal from the m...
#  3            3  Inserts used in plastic parts provide a place ...
#  4            4  Ultrasonic insertion is when an insert is “vib...
#  5            5  This method uses a heated tool, like a solderi...
#  6            6  This process is used to hollow out thick secti...
#  7            7  The overmolding process is when a flexible mat...
#  8            8  The most widely used overmolding process is in...
#  9            9  This is a multi-material overmolding process t...
#  10          10  Because the thickness of the material will be ...
#  11          11  Parts with walls of uniform thickness allow th...,
#  <function min>)

# %%
# Create an NMF instance: model
# the 10 components will be the topics
model = NMF(n_components=10, random_state=5)
# Fit the model to TF-IDF
model.fit(X)
# Transform the TF-IDF: nmf_features
nmf_features = model.transform(X)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:294: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   FutureWarning,

# %%
X.shape
# Out:
# (12, 115)

# %%
nmf_features.shape
# Out:
# (12, 10)

# %%
model.components_.shape
# Out:
# (10, 115)

# %%
# Create a DataFrame: components_df
components_df = pd.DataFrame(model.components_, columns=vect.get_feature_names())
components_df
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
#    acceptable  accepting    adding    allow    angle  attaching     avoid  \
# 0    0.000000   0.000000  0.000000  0.00000  0.00000   0.000000  0.000000
# 1    0.000000   0.207319  0.000000  0.00000  0.00000   0.207319  0.000000
# 2    0.000000   0.000000  0.000000  0.00000  0.00000   0.000000  0.000000
# 3    0.000000   0.003538  0.000000  0.00000  0.40673   0.003538  0.000000
# 4    0.000000   0.000000  0.259361  0.00000  0.00000   0.000000  0.000000
# 5    0.361093   0.000000  0.000000  0.00000  0.00000   0.000000  0.000000
# 6    0.000000   0.000000  0.000000  0.00000  0.00000   0.000000  0.249124
# 7    0.000000   0.000000  0.000000  0.00000  0.00000   0.000000  0.000000
# 8    0.000000   0.000000  0.000000  0.32501  0.00000   0.000000  0.000000
# 9    0.000000   0.000000  0.000000  0.00000  0.00000   0.000000  0.000000
#
#     barrels   bending      bond  ...    ultrasonic  uniform       use  \
# 0  0.000000  0.000000  0.213460  ...  0.000000e+00  0.00000  0.000000
# 1  0.000000  0.000000  0.000000  ...  0.000000e+00  0.00000  0.000000
# 2  0.000000  0.000000  0.000000  ...  0.000000e+00  0.00000  0.000000
# 3  0.000000  0.000000  0.000000  ...  2.020691e-09  0.00000  0.203365
# 4  0.000000  0.518722  0.000000  ...  0.000000e+00  0.00000  0.000000
# 5  0.000000  0.000000  0.000000  ...  0.000000e+00  0.00000  0.000000
# 6  0.000004  0.000000  0.005156  ...  0.000000e+00  0.00000  0.000000
# 7  0.000000  0.000000  0.000066  ...  8.706366e-01  0.00000  0.000000
# 8  0.000000  0.000000  0.000000  ...  0.000000e+00  0.32501  0.000000
# 9  0.357180  0.000000  0.000000  ...  0.000000e+00  0.00000  0.000000
#
#        used      uses         using  varying      vibrated    walls    widely
# 0  0.150605  0.000000  0.000000e+00  0.00000  0.000000e+00  0.00000  0.265345
# 1  0.280607  0.000000  0.000000e+00  0.00000  0.000000e+00  0.00000  0.000524
# 2  0.010227  0.329317  0.000000e+00  0.00000  0.000000e+00  0.00000  0.012251
# 3  0.008963  0.000000  6.735638e-10  0.00000  6.735638e-10  0.00000  0.017274
# 4  0.161830  0.000000  0.000000e+00  0.00000  0.000000e+00  0.00000  0.002695
# 5  0.226777  0.000000  0.000000e+00  0.00000  0.000000e+00  0.00000  0.005849
# 6  0.000000  0.000000  0.000000e+00  0.00000  0.000000e+00  0.00000  0.000000
# 7  0.001014  0.000000  2.902122e-01  0.00000  2.902122e-01  0.00000  0.000000
# 8  0.003859  0.000000  0.000000e+00  0.32501  0.000000e+00  0.32501  0.003192
# 9  0.006140  0.000000  0.000000e+00  0.00000  0.000000e+00  0.00000  0.006654
#
# [10 rows x 115 columns]

# %%
for topic in range(components_df.shape[0]):
    tmp = components_df.iloc[topic]
    print(f'For topic {topic+1} the words with the highest value are:')
    print(tmp.nlargest(10))
    print('\n')
# Out:
# For topic 1 the words with the highest value are:
# flexible       0.596860
# substrate      0.596860
# material       0.592745
# molded         0.412844
# overmolding    0.355998
# process        0.310284
# directly       0.265345
# placed         0.265345
# pre            0.265345
# shot           0.265345
# Name: 0, dtype: float64
#
#
# For topic 2 the words with the highest value are:
# fasteners    0.391095
# inserts      0.391095
# screws       0.391095
# parts        0.339184
# used         0.280607
# provide      0.246739
# accepting    0.207319
# attaching    0.207319
# bosses       0.207319
# mating       0.207319
# Name: 1, dtype: float64
#
#
# For topic 3 the words with the highest value are:
# insert       0.509547
# heat         0.329317
# heated       0.329317
# iron         0.329317
# like         0.329317
# melts        0.329317
# method       0.329317
# presses      0.329317
# soldering    0.329317
# tool         0.329317
# Name: 2, dtype: float64
#
#
# For topic 4 the words with the highest value are:
# mold       0.632584
# angle      0.406730
# draft      0.406730
# closing    0.203365
# depends    0.203365
# depth      0.203365
# drafts     0.203365
# end        0.203365
# functio    0.203365
# given      0.203365
# Name: 3, dtype: float64
#
#
# For topic 5 the words with the highest value are:
# bending      0.518722
# increase     0.518722
# ribs         0.518722
# stiffness    0.518722
# adding       0.259361
# design       0.259361
# increases    0.259361
# inertia      0.259361
# moment       0.259361
# thickness    0.196656
# Name: 4, dtype: float64
#
#
# For topic 6 the words with the highest value are:
# acceptable    0.361093
# hollow        0.361093
# option        0.361093
# sections      0.361093
# sink          0.361093
# coring        0.310084
# process       0.247018
# used          0.226777
# directly      0.005849
# placed        0.005849
# Name: 5, dtype: float64
#
#
# For topic 7 the words with the highest value are:
# material         0.345529
# avoid            0.249124
# employed         0.249124
# excessive        0.249124
# greater          0.249124
# intersections    0.249124
# means            0.249124
# occurring        0.249124
# opposite         0.249124
# rib              0.249124
# Name: 6, dtype: float64
#
#
# For topic 8 the words with the highest value are:
# ultrasonic    0.870637
# device        0.290212
# horn          0.290212
# insertion     0.290212
# mounted       0.290212
# transducer    0.290212
# using         0.290212
# vibrated      0.290212
# called        0.249295
# place         0.225139
# Name: 7, dtype: float64
#
#
# For topic 9 the words with the highest value are:
# allow           0.32501
# cavity          0.32501
# does            0.32501
# easily          0.32501
# fills           0.32501
# forced          0.32501
# molten          0.32501
# restrictions    0.32501
# uniform         0.32501
# varying         0.32501
# Name: 8, dtype: float64
#
#
# For topic 10 the words with the highest value are:
# barrels         0.357180
# incorporates    0.357180
# injection       0.357180
# multi           0.357180
# requires        0.357180
# special         0.357180
# machine         0.319751
# molding         0.312729
# overmolding     0.272690
# process         0.244446
# Name: 9, dtype: float64
